# %% [markdown]
# # Proyek Analisis Data: Air Quality Dataset
# - **Nama:** I Putu Eka Putra Juniawan
# - **Email:** ekaputrajuniawan@gmail.com
# - **ID Dicoding:** ptekaputra

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Pertanyaan 1: Bagaimana variasi kualitas udara (PM2.5, PM10) berdasarkan musim (spring, summer, autumn, winter)?
#
#   `Mengidentifikasi musim yang memiliki tingkat polusi tertinggi dan terendah untuk membantu membuat kebijakan mitigasi polusi udara yang lebih efektif di musim tertentu.`
#
# - Pertanyaan 2: Apakah ada hubungan antara kecepatan angin (WSPM) dan konsentrasi PM2.5 di berbagai musim?
#
#   `Mengidentifikasi apakah kecepatan angin mempengaruhi penyebaran atau akumulasi polusi udara (PM2.5) di musim-musim tertentu, yang bisa digunakan untuk memahami pola penyebaran polusi.`
#
# - Pertanyaan 3: Bagaimana distribusi polutan berbahaya (SO2, NO2, CO) di berbagai musim dan jam dalam sehari?
#
#   `Mengetahui waktu-waktu kritis dengan konsentrasi polutan yang lebih tinggi di siang atau malam hari dapat membantu pengelolaan kualitas udara di waktu-waktu tertentu.`
#
# - Pertanyaan 4: Bagaimana pengaruh curah hujan (RAIN) terhadap konsentrasi polutan (PM2.5, PM10)?
#
#   `Mengetahui apakah hujan membantu mengurangi polusi udara, yang bisa bermanfaat untuk perencanaan lingkungan di daerah perkotaan.`
#
# - Pertanyaan 5: Apakah ada tren perubahan kualitas udara (PM2.5, PM10) dari tahun 2013 hingga 2017?
#
#   `Mengetahui apakah kualitas udara semakin membaik atau memburuk seiring waktu, dan dapat menjadi dasar untuk mengevaluasi efektivitas kebijakan pengurangan emisi yang telah diterapkan.`

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import streamlit as st

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# Import raw dataset

# %%
aotizhongxin_df = pd.read_csv("./data/raw/PRSA_Data_Aotizhongxin_20130301-20170228.csv")
changping_df = pd.read_csv("./data/raw/PRSA_Data_Changping_20130301-20170228.csv")
dingling_df = pd.read_csv("./data/raw/PRSA_Data_Dingling_20130301-20170228.csv")
dongsi_df = pd.read_csv("./data/raw/PRSA_Data_Dongsi_20130301-20170228.csv")
guanyuan_df = pd.read_csv("./data/raw/PRSA_Data_Guanyuan_20130301-20170228.csv")
gucheng_df = pd.read_csv("./data/raw/PRSA_Data_Gucheng_20130301-20170228.csv")
huairou_df = pd.read_csv("./data/raw/PRSA_Data_Huairou_20130301-20170228.csv")
nongzhanguan_df = pd.read_csv("./data/raw/PRSA_Data_Nongzhanguan_20130301-20170228.csv")
shunyi_df = pd.read_csv("./data/raw/PRSA_Data_Shunyi_20130301-20170228.csv")
tiantan_df = pd.read_csv("./data/raw/PRSA_Data_Tiantan_20130301-20170228.csv")
wanliu_df = pd.read_csv("./data/raw/PRSA_Data_Wanliu_20130301-20170228.csv")
wanshouxigong_df = pd.read_csv("./data/raw/PRSA_Data_Wanshouxigong_20130301-20170228.csv")

# %% [markdown]
# #### Aotizhongxin dataset

# %%
aotizhongxin_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin

# %% [markdown]
# #### Changping dataset

# %%
changping_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  13.0   7.0  300.0  85.0  -2.3
# 1   2  2013      3    1     1    3.0   3.0   6.0   6.0  300.0  85.0  -2.5
# 2   3  2013      3    1     2    3.0   3.0  22.0  13.0  400.0  74.0  -3.0
# 3   4  2013      3    1     3    3.0   6.0  12.0   8.0  300.0  81.0  -3.6
# 4   5  2013      3    1     4    3.0   3.0  14.0   8.0  300.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM    station
# 0  1020.8 -19.7   0.0    E   0.5  Changping
# 1  1021.3 -19.0   0.0  ENE   0.7  Changping
# 2  1021.3 -19.9   0.0  ENE   0.2  Changping
# 3  1021.8 -19.1   0.0  NNE   1.0  Changping
# 4  1022.3 -19.4   0.0    N   2.1  Changping

# %% [markdown]
# #### Dingling dataset

# %%
dingling_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0  3.0  NaN  200.0  82.0  -2.3
# 1   2  2013      3    1     1    7.0   7.0  3.0  NaN  200.0  80.0  -2.5
# 2   3  2013      3    1     2    5.0   5.0  3.0  2.0  200.0  79.0  -3.0
# 3   4  2013      3    1     3    6.0   6.0  3.0  NaN  200.0  79.0  -3.6
# 4   5  2013      3    1     4    5.0   5.0  3.0  NaN  200.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM   station
# 0  1020.8 -19.7   0.0    E   0.5  Dingling
# 1  1021.3 -19.0   0.0  ENE   0.7  Dingling
# 2  1021.3 -19.9   0.0  ENE   0.2  Dingling
# 3  1021.8 -19.1   0.0  NNE   1.0  Dingling
# 4  1022.3 -19.4   0.0    N   2.1  Dingling

# %% [markdown]
# #### Dongsi dataset

# %%
dongsi_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    9.0   9.0  3.0  17.0  300.0  89.0  -0.5
# 1   2  2013      3    1     1    4.0   4.0  3.0  16.0  300.0  88.0  -0.7
# 2   3  2013      3    1     2    7.0   7.0  NaN  17.0  300.0  60.0  -1.2
# 3   4  2013      3    1     3    3.0   3.0  5.0  18.0    NaN   NaN  -1.4
# 4   5  2013      3    1     4    3.0   3.0  7.0   NaN  200.0  84.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM station
# 0  1024.5 -21.4   0.0  NNW   5.7  Dongsi
# 1  1025.1 -22.1   0.0   NW   3.9  Dongsi
# 2  1025.3 -24.6   0.0  NNW   5.3  Dongsi
# 3  1026.2 -25.5   0.0    N   4.9  Dongsi
# 4  1027.1 -24.5   0.0  NNW   3.2  Dongsi

# %% [markdown]
# #### Guanyuan dataset

# %%
guanyuan_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0  14.0  20.0  300.0  69.0  -0.7
# 1   2  2013      3    1     1    4.0   4.0  13.0  17.0  300.0  72.0  -1.1
# 2   3  2013      3    1     2    3.0   3.0  10.0  19.0  300.0  69.0  -1.1
# 3   4  2013      3    1     3    3.0   6.0   7.0  24.0  400.0  62.0  -1.4
# 4   5  2013      3    1     4    3.0   6.0   5.0  14.0  400.0  71.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM   station
# 0  1023.0 -18.8   0.0  NNW   4.4  Guanyuan
# 1  1023.2 -18.2   0.0    N   4.7  Guanyuan
# 2  1023.5 -18.2   0.0  NNW   5.6  Guanyuan
# 3  1024.5 -19.4   0.0   NW   3.1  Guanyuan
# 4  1025.2 -19.5   0.0    N   2.0  Guanyuan

# %% [markdown]
# #### Gucheng dataset

# %%
gucheng_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    6.0  18.0  5.0  NaN  800.0  88.0   0.1
# 1   2  2013      3    1     1    6.0  15.0  5.0  NaN  800.0  88.0  -0.3
# 2   3  2013      3    1     2    5.0  18.0  NaN  NaN  700.0  52.0  -0.7
# 3   4  2013      3    1     3    6.0  20.0  6.0  NaN    NaN   NaN  -1.0
# 4   5  2013      3    1     4    5.0  17.0  5.0  NaN  600.0  73.0  -1.3
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1021.1 -18.6   0.0   NW   4.4  Gucheng
# 1  1021.5 -19.0   0.0   NW   4.0  Gucheng
# 2  1021.5 -19.8   0.0  WNW   4.6  Gucheng
# 3  1022.7 -21.2   0.0    W   2.8  Gucheng
# 4  1023.0 -21.4   0.0  WNW   3.6  Gucheng

# %% [markdown]
# #### Huairou dataset

# %%
huairou_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    7.0   7.0  3.0  2.0  100.0  91.0  -2.3
# 1   2  2013      3    1     1    4.0   4.0  3.0  NaN  100.0  92.0  -2.7
# 2   3  2013      3    1     2    4.0   4.0  NaN  NaN  100.0  91.0  -3.2
# 3   4  2013      3    1     3    3.0   3.0  3.0  2.0    NaN   NaN  -3.3
# 4   5  2013      3    1     4    3.0   3.0  7.0  NaN  300.0  86.0  -4.1
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1020.3 -20.7   0.0  WNW   3.1  Huairou
# 1  1020.8 -20.5   0.0  NNW   1.5  Huairou
# 2  1020.6 -21.4   0.0   NW   1.8  Huairou
# 3  1021.3 -23.7   0.0  NNW   2.4  Huairou
# 4  1022.1 -22.7   0.0  NNW   2.2  Huairou

# %% [markdown]
# #### Nongzhanguan dataset

# %%
nongzhanguan_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    5.0  14.0  4.0  12.0  200.0  85.0  -0.5
# 1   2  2013      3    1     1    8.0  12.0  6.0  14.0  200.0  84.0  -0.7
# 2   3  2013      3    1     2    3.0   6.0  5.0  14.0  200.0  83.0  -1.2
# 3   4  2013      3    1     3    5.0   5.0  5.0  14.0  200.0  84.0  -1.4
# 4   5  2013      3    1     4    5.0   5.0  6.0  21.0  200.0  77.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1024.5 -21.4   0.0  NNW   5.7  Nongzhanguan
# 1  1025.1 -22.1   0.0   NW   3.9  Nongzhanguan
# 2  1025.3 -24.6   0.0  NNW   5.3  Nongzhanguan
# 3  1026.2 -25.5   0.0    N   4.9  Nongzhanguan
# 4  1027.1 -24.5   0.0  NNW   3.2  Nongzhanguan

# %% [markdown]
# #### Shunyi dataset

# %%
shunyi_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  3.0  8.0  300.0  44.0  -0.9
# 1   2  2013      3    1     1   12.0  12.0  3.0  7.0  300.0  47.0  -1.1
# 2   3  2013      3    1     2   14.0  14.0  NaN  7.0  200.0  22.0  -1.7
# 3   4  2013      3    1     3   12.0  12.0  3.0  5.0    NaN   NaN  -2.1
# 4   5  2013      3    1     4   12.0  12.0  3.0  NaN  200.0  11.0  -2.4
#
#      PRES  DEWP  RAIN  wd  WSPM station
# 0  1025.8 -20.5   0.0  NW   9.3  Shunyi
# 1  1026.1 -21.3   0.0  NW   9.4  Shunyi
# 2  1026.2 -23.0   0.0  NW   8.6  Shunyi
# 3  1027.3 -23.3   0.0  NW   6.6  Shunyi
# 4  1027.7 -22.9   0.0  NW   4.5  Shunyi

# %% [markdown]
# #### Tiantan dataset

# %%
tiantan_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    6.0   6.0  4.0   8.0  300.0  81.0  -0.5
# 1   2  2013      3    1     1    6.0  29.0  5.0   9.0  300.0  80.0  -0.7
# 2   3  2013      3    1     2    6.0   6.0  4.0  12.0  300.0  75.0  -1.2
# 3   4  2013      3    1     3    6.0   6.0  4.0  12.0  300.0  74.0  -1.4
# 4   5  2013      3    1     4    5.0   5.0  7.0  15.0  400.0  70.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1024.5 -21.4   0.0  NNW   5.7  Tiantan
# 1  1025.1 -22.1   0.0   NW   3.9  Tiantan
# 2  1025.3 -24.6   0.0  NNW   5.3  Tiantan
# 3  1026.2 -25.5   0.0    N   4.9  Tiantan
# 4  1027.1 -24.5   0.0  NNW   3.2  Tiantan

# %% [markdown]
# #### Wanliu dataset

# %%
wanliu_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    8.0   8.0  6.0  28.0  400.0  52.0  -0.7
# 1   2  2013      3    1     1    9.0   9.0  6.0  28.0  400.0  50.0  -1.1
# 2   3  2013      3    1     2    3.0   6.0  NaN  19.0  400.0  55.0  -1.1
# 3   4  2013      3    1     3   11.0  30.0  8.0  14.0    NaN   NaN  -1.4
# 4   5  2013      3    1     4    3.0  13.0  9.0   NaN  300.0  54.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM station
# 0  1023.0 -18.8   0.0  NNW   4.4  Wanliu
# 1  1023.2 -18.2   0.0    N   4.7  Wanliu
# 2  1023.5 -18.2   0.0  NNW   5.6  Wanliu
# 3  1024.5 -19.4   0.0   NW   3.1  Wanliu
# 4  1025.2 -19.5   0.0    N   2.0  Wanliu

# %% [markdown]
# #### Wanshouxigong dataset

# %%
wanshouxigong_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    9.0   9.0  6.0  17.0  200.0  62.0   0.3
# 1   2  2013      3    1     1   11.0  11.0  7.0  14.0  200.0  66.0  -0.1
# 2   3  2013      3    1     2    8.0   8.0  NaN  16.0  200.0  59.0  -0.6
# 3   4  2013      3    1     3    8.0   8.0  3.0  16.0    NaN   NaN  -0.7
# 4   5  2013      3    1     4    8.0   8.0  3.0   NaN  300.0  36.0  -0.9
#
#      PRES  DEWP  RAIN   wd  WSPM        station
# 0  1021.9 -19.0   0.0  WNW   2.0  Wanshouxigong
# 1  1022.4 -19.3   0.0  WNW   4.4  Wanshouxigong
# 2  1022.6 -19.7   0.0  WNW   4.7  Wanshouxigong
# 3  1023.5 -20.9   0.0   NW   2.6  Wanshouxigong
# 4  1024.1 -21.7   0.0  WNW   2.5  Wanshouxigong

# %% [markdown]
# **Insight:**
# - Data menunjukkan variabilitas tinggi dalam berbagai polutan udara, yang menunjukkan bahwa kualitas udara bervariasi secara signifikan di seluruh wilayah dan waktu pengukuran.
# - Beberapa polutan, seperti CO, menunjukkan level yang sangat tinggi di beberapa lokasi dan waktu, yang bisa menjadi perhatian khusus terkait kesehatan masyarakat.

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# Karena struktur dataset sama, yang membedakan hanya value pada kolom station, maka dari itu saya merge semua dataset menjadi 1 dataset gabungan (all_station_df)

# %%
all_stations_df = pd.concat([
    aotizhongxin_df, changping_df, dingling_df, dongsi_df, guanyuan_df, gucheng_df,
    huairou_df, nongzhanguan_df, shunyi_df, tiantan_df, wanliu_df, wanshouxigong_df
], ignore_index=True)

# %%
all_stations_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin

# %%
all_stations_df.describe()
# Out:
#                   No           year          month            day  \
# count  420768.000000  420768.000000  420768.000000  420768.000000
# mean    17532.500000    2014.662560       6.522930      15.729637
# std     10122.116943       1.177198       3.448707       8.800102
# min         1.000000    2013.000000       1.000000       1.000000
# 25%      8766.750000    2014.000000       4.000000       8.000000
# 50%     17532.500000    2015.000000       7.000000      16.000000
# 75%     26298.250000    2016.000000      10.000000      23.000000
# max     35064.000000    2017.000000      12.000000      31.000000
#
#                 hour          PM2.5           PM10            SO2  \
# count  420768.000000  412029.000000  414319.000000  411747.000000
# mean       11.500000      79.793428     104.602618      15.830835
# std         6.922195      80.822391      91.772426      21.650603
# min         0.000000       2.000000       2.000000       0.285600
# 25%         5.750000      20.000000      36.000000       3.000000
# 50%        11.500000      55.000000      82.000000       7.000000
# 75%        17.250000     111.000000     145.000000      20.000000
# max        23.000000     999.000000     999.000000     500.000000
#
#                  NO2             CO             O3           TEMP  \
# count  408652.000000  400067.000000  407491.000000  420370.000000
# mean       50.638586    1230.766454      57.372271      13.538976
# std        35.127912    1160.182716      56.661607      11.436139
# min         1.026500     100.000000       0.214200     -19.900000
# 25%        23.000000     500.000000      11.000000       3.100000
# 50%        43.000000     900.000000      45.000000      14.500000
# 75%        71.000000    1500.000000      82.000000      23.300000
# max       290.000000   10000.000000    1071.000000      41.600000
#
#                 PRES           DEWP           RAIN           WSPM
# count  420375.000000  420365.000000  420378.000000  420450.000000
# mean     1010.746982       2.490822       0.064476       1.729711
# std        10.474055      13.793847       0.821004       1.246386
# min       982.400000     -43.400000       0.000000       0.000000
# 25%      1002.300000      -8.900000       0.000000       0.900000
# 50%      1010.400000       3.100000       0.000000       1.400000
# 75%      1019.000000      15.100000       0.000000       2.200000
# max      1042.800000      29.100000      72.500000      13.200000

# %%
all_stations_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420768 entries, 0 to 420767
# Data columns (total 18 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   No       420768 non-null  int64
#  1   year     420768 non-null  int64
#  2   month    420768 non-null  int64
#  3   day      420768 non-null  int64
#  4   hour     420768 non-null  int64
#  5   PM2.5    412029 non-null  float64
#  6   PM10     414319 non-null  float64
#  7   SO2      411747 non-null  float64
#  8   NO2      408652 non-null  float64
#  9   CO       400067 non-null  float64
#  10  O3       407491 non-null  float64
#  11  TEMP     420370 non-null  float64
#  12  PRES     420375 non-null  float64
#  13  DEWP     420365 non-null  float64
#  14  RAIN     420378 non-null  float64
#  15  wd       418946 non-null  object
#  16  WSPM     420450 non-null  float64
#  17  station  420768 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 57.8+ MB

# %% [markdown]
# #### 1. Distribusi Data untuk Kolom Numerik

# %%
all_stations_df.describe()
# Out:
#                   No           year          month            day  \
# count  420768.000000  420768.000000  420768.000000  420768.000000
# mean    17532.500000    2014.662560       6.522930      15.729637
# std     10122.116943       1.177198       3.448707       8.800102
# min         1.000000    2013.000000       1.000000       1.000000
# 25%      8766.750000    2014.000000       4.000000       8.000000
# 50%     17532.500000    2015.000000       7.000000      16.000000
# 75%     26298.250000    2016.000000      10.000000      23.000000
# max     35064.000000    2017.000000      12.000000      31.000000
#
#                 hour          PM2.5           PM10            SO2  \
# count  420768.000000  412029.000000  414319.000000  411747.000000
# mean       11.500000      79.793428     104.602618      15.830835
# std         6.922195      80.822391      91.772426      21.650603
# min         0.000000       2.000000       2.000000       0.285600
# 25%         5.750000      20.000000      36.000000       3.000000
# 50%        11.500000      55.000000      82.000000       7.000000
# 75%        17.250000     111.000000     145.000000      20.000000
# max        23.000000     999.000000     999.000000     500.000000
#
#                  NO2             CO             O3           TEMP  \
# count  408652.000000  400067.000000  407491.000000  420370.000000
# mean       50.638586    1230.766454      57.372271      13.538976
# std        35.127912    1160.182716      56.661607      11.436139
# min         1.026500     100.000000       0.214200     -19.900000
# 25%        23.000000     500.000000      11.000000       3.100000
# 50%        43.000000     900.000000      45.000000      14.500000
# 75%        71.000000    1500.000000      82.000000      23.300000
# max       290.000000   10000.000000    1071.000000      41.600000
#
#                 PRES           DEWP           RAIN           WSPM
# count  420375.000000  420365.000000  420378.000000  420450.000000
# mean     1010.746982       2.490822       0.064476       1.729711
# std        10.474055      13.793847       0.821004       1.246386
# min       982.400000     -43.400000       0.000000       0.000000
# 25%      1002.300000      -8.900000       0.000000       0.900000
# 50%      1010.400000       3.100000       0.000000       1.400000
# 75%      1019.000000      15.100000       0.000000       2.200000
# max      1042.800000      29.100000      72.500000      13.200000

# %% [markdown]
# **Insight:**
#
# - Menilai sebaran data, nilai min, max, dan apakah terdapat outliers yang signifikan.
# - Data cuaca dan polutan sering kali memiliki pola musiman atau harian, yang bisa jadi normal memiliki fluktuasi.

# %% [markdown]
# #### 2. Memeriksa Missing Values (Nilai yang Hilang)

# %%
missing_values_percentage = (all_stations_df.isnull().sum() / len(all_stations_df)) * 100
print(missing_values_percentage)
# Out:
# No         0.000000
# year       0.000000
# month      0.000000
# day        0.000000
# hour       0.000000
# PM2.5      2.076916
# PM10       1.532674
# SO2        2.143937
# NO2        2.879497
# CO         4.919813
# O3         3.155421
# TEMP       0.094589
# PRES       0.093401
# DEWP       0.095777
# RAIN       0.092688
# wd         0.433018
# WSPM       0.075576
# station    0.000000
# dtype: float64

# %% [markdown]
# **Insight:**
#
# - Jika persentase missing values rendah (<5%), bisa diisi dengan median atau mean.
# - Jika persentasenya tinggi, perlu dipertimbangkan apakah kolom tersebut dapat dihapus atau data tersebut dibiarkan apa adanya.
# - Dari data di atas, semua missing value < 5% sehingga nilai yang kosong diisi dengan nilai rata-ratanya

# %% [markdown]
# #### 3. Distribusi Kategori (Kolom Non-Numerik)

# %%
print(all_stations_df['wd'].value_counts())
print(all_stations_df['station'].value_counts())
# Out:
# wd
# NE     43335
# ENE    34142
# NW     32600
# N      30869
# E      29752
# SW     28756
# NNE    28232
# NNW    25326
# WNW    24375
# ESE    24220
# SSW    22563
# SE     20074
# WSW    20040
# S      19405
# SSE    17694
# W      17563
# Name: count, dtype: int64
# station
# Aotizhongxin     35064
# Changping        35064
# Dingling         35064
# Dongsi           35064
# Guanyuan         35064
# Gucheng          35064
# Huairou          35064
# Nongzhanguan     35064
# Shunyi           35064
# Tiantan          35064
# Wanliu           35064
# Wanshouxigong    35064
# Name: count, dtype: int64

# %% [markdown]
# **Insight:**
#
# - Menilai variasi arah angin yang tercatat.
# - Memastikan tidak ada stasiun pengukuran yang hilang atau memiliki data tidak lengkap.

# %% [markdown]
# #### 4. Outliers

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.boxplot(data=all_stations_df[['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'WSPM']])
plt.title("Boxplot of Air Pollutants")
plt.show()

# %% [markdown]
# **Insight:**
#
# - Dapat dilihat adanya outliers yang cukup signifikan, terutama di variabel CO, serta sedikit outliers pada variabel PM2.5, PM10, dan O3.

# %% [markdown]
# #### 5. Memeriksa Konsistensi Data Waktu

# %%
all_stations_df['datetime'] = pd.to_datetime(all_stations_df[['year', 'month', 'day', 'hour']])
print(all_stations_df['datetime'].min(), all_stations_df['datetime'].max())
# Out:
# 2013-03-01 00:00:00 2017-02-28 23:00:00

# %% [markdown]
# **Insight:**
# - Penulisan waktu sudah konsisten

# %% [markdown]
# #### 6. Pola Musiman dan Waktu

# %%
monthly_avg = all_stations_df.groupby('month')[['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'WSPM']].mean()
print(monthly_avg)
# Out:
#             PM2.5        PM10        SO2        NO2           CO         O3  \
# month
# 1       93.667037  113.227543  31.458144  61.763499  1852.933132  27.633733
# 2       87.572234  102.682735  28.319241  50.213573  1384.996511  40.734810
# 3       94.660678  136.040075  27.999596  60.124179  1310.230474  51.041261
# 4       72.734890  116.962595  14.224056  47.280261   840.493265  70.185707
# 5       63.105338  107.038514  14.087248  42.534000   795.234500  92.028567
# 6       69.091971   86.730518   7.902758  39.319569   987.904479  94.692310
# 7       71.744853   84.631258   5.545213  35.822804   891.855104  95.086942
# 8       53.473014   71.511467   4.669854  36.103815   825.603120  87.871592
# 9       61.478105   79.673490   6.312925  45.616774   925.164610  55.094877
# 10      91.726800  112.550553   8.665165  59.738056  1150.505966  29.927943
# 11      93.331519  118.113954  15.331449  61.895454  1660.204855  19.871741
# 12     104.581244  125.480496  25.767412  66.656259  2167.458906  21.387220
#
#             TEMP         PRES       DEWP      WSPM
# month
# 1      -1.797300  1022.113822 -14.754206  1.875282
# 2       1.123071  1020.306765 -13.002845  2.007847
# 3       8.348409  1013.957400  -7.945248  1.976319
# 4      15.328909  1008.307401   0.187078  2.173886
# 5      21.482056  1002.394231   6.877074  2.065607
# 6      24.554861   999.335043  15.613424  1.576930
# 7      27.194170   998.131404  19.920511  1.497536
# 8      26.642028  1001.233726  18.930494  1.448845
# 9      20.765633  1008.669595  13.967150  1.349296
# 10     13.450143  1014.897046   5.624504  1.405987
# 11      4.770448  1018.774547  -4.614541  1.582403
# 12     -0.231803  1021.516852 -11.906399  1.814481

# %% [markdown]
# **Insight:**
#
# - Memberikan pandangan awal apakah ada tren musiman terkait polutan udara.
# - Berguna untuk menentukan langkah eksplorasi lebih lanjut terkait musim atau waktu.

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### Mengisi missing value dengan rata-rata untuk kolom numerik dan mode untuk kolom kategorikal

# %%
all_stations_df['PM2.5'].fillna(all_stations_df['PM2.5'].mean(), inplace=True)
all_stations_df['PM10'].fillna(all_stations_df['PM10'].mean(), inplace=True)
all_stations_df['SO2'].fillna(all_stations_df['SO2'].mean(), inplace=True)
all_stations_df['NO2'].fillna(all_stations_df['NO2'].mean(), inplace=True)
all_stations_df['CO'].fillna(all_stations_df['CO'].mean(), inplace=True)
all_stations_df['O3'].fillna(all_stations_df['O3'].mean(), inplace=True)
all_stations_df['TEMP'].fillna(all_stations_df['TEMP'].mean(), inplace=True)
all_stations_df['PRES'].fillna(all_stations_df['PRES'].mean(), inplace=True)
all_stations_df['DEWP'].fillna(all_stations_df['DEWP'].mean(), inplace=True)
all_stations_df['RAIN'].fillna(all_stations_df['RAIN'].mean(), inplace=True)
all_stations_df['wd'].fillna(all_stations_df['wd'].mode()[0], inplace=True)  # Mode untuk kolom kategorikal
all_stations_df['WSPM'].fillna(all_stations_df['WSPM'].mean(), inplace=True)

# Mengecek ulang apakah masih ada missing values
print(all_stations_df.isnull().sum())
# Out:
# No          0
# year        0
# month       0
# day         0
# hour        0
# PM2.5       0
# PM10        0
# SO2         0
# NO2         0
# CO          0
# O3          0
# TEMP        0
# PRES        0
# DEWP        0
# RAIN        0
# wd          0
# WSPM        0
# station     0
# datetime    0
# dtype: int64
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_19600\1729181493.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_stations_df['PM2.5'].fillna(all_stations_df['PM2.5'].mean(), inplace=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_19600\1729181493.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_stations_df['PM10'].fillna(all_stations_df['PM10'].mean(), inplace=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_19600\1729181493.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_stations_df['SO2'].fillna(all_stations_df['SO2'].mean(), inplace=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_19600\1729181493.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_stations_df['NO2'].fillna(all_stations_df['NO2'].mean(), inplace=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_19600\1729181493.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_stations_df['CO'].fillna(all_stations_df['CO'].mean(), inplace=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_19600\1729181493.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_stations_df['O3'].fillna(all_stations_df['O3'].mean(), inplace=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_19600\1729181493.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_stations_df['TEMP'].fillna(all_stations_df['TEMP'].mean(), inplace=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_19600\1729181493.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_stations_df['PRES'].fillna(all_stations_df['PRES'].mean(), inplace=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_19600\1729181493.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_stations_df['DEWP'].fillna(all_stations_df['DEWP'].mean(), inplace=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_19600\1729181493.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_stations_df['RAIN'].fillna(all_stations_df['RAIN'].mean(), inplace=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_19600\1729181493.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_stations_df['wd'].fillna(all_stations_df['wd'].mode()[0], inplace=True)  # Mode untuk kolom kategorikal
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_19600\1729181493.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_stations_df['WSPM'].fillna(all_stations_df['WSPM'].mean(), inplace=True)

# %% [markdown]
# #### Memperbaiki outlier

# %% [markdown]
# Berdasarkan proses assesing data sebelumnya, permasalahan yang paling menonjol dalam data yaitu outlier yang sangat jauh dari nilai mean. Maka dari itu diperlukan untuk menormalkan data dengan memperbaiki nilai outliernya/ menghapus data bila perlu.

# %%
# Fungsi untuk mendeteksi dan menghapus outliers menggunakan IQR
def remove_outliers(df, columns):
    for col in columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        # Menghapus data yang berada di luar lower_bound dan upper_bound
        df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]
    return df

# Daftar kolom numerik yang akan diperiksa outliers
numeric_columns = ['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'WSPM']

# Menghapus outliers pada kolom yang dipilih
all_stations_df_cleaned = remove_outliers(all_stations_df, numeric_columns)

# %% [markdown]
# - IQR (Interquartile Range) digunakan untuk mendeteksi outliers. Data yang berada di luar rentang (Q1 - 1.5 * IQR) dan (Q3 + 1.5 * IQR) dianggap sebagai outliers dan dihapus.
# - Kode di atas secara otomatis memproses setiap kolom numerik dalam daftar numeric_columns dan menghapus baris yang berisi outliers.

# %% [markdown]
# Visualisasi setelah penghapusan outlier

# %%
# Daftar kolom yang akan dipetakan
columns_to_plot = ['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'WSPM']

# Membuat figure dengan 2 kolom dan 5 baris
fig, axes = plt.subplots(5, 2, figsize=(12, 20))  # Ukuran diperbesar untuk menyesuaikan semua grafik

# Flatten axes untuk memudahkan iterasi
axes = axes.flatten()

# Looping untuk membuat boxplot pada setiap subplot
for i, column in enumerate(columns_to_plot):
    sns.boxplot(y=all_stations_df_cleaned[column], ax=axes[i])
    axes[i].set_title(f"Boxplot of {column}")

# Menyesuaikan tata letak agar lebih rapi
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:**
# 1. Polutan Partikulat (PM2.5 dan PM10):
#     - PM2.5 dan PM10 memiliki distribusi yang menunjukkan beberapa outliers di bagian atas. Kedua polutan ini menunjukkan bahwa mayoritas data berada pada level sedang (sekitar 50-100 µg/m³), tetapi ada periode di mana konsentrasi polutan jauh lebih tinggi (> 200 µg/m³), yang menunjukkan polusi udara yang berbahaya di beberapa waktu atau tempat.
# 2. Polutan Gas (SO2, NO2, CO, O3):
#     - SO2 dan NO2 menunjukkan distribusi yang lebih terkonsentrasi, dengan median yang relatif rendah, namun tetap memiliki outliers. Ini menunjukkan bahwa meskipun rata-rata polutan ini tidak terlalu tinggi, ada waktu atau tempat tertentu di mana konsentrasinya meningkat secara signifikan.
#     - CO memiliki distribusi yang lebih luas, dengan median di sekitar 1000 µg/m³ dan beberapa outliers yang signifikan, mencerminkan adanya variasi besar dalam konsentrasi karbon monoksida.
#     - O3 juga menunjukkan outliers di bagian atas, namun distribusinya lebih terkonsentrasi di sekitar level sedang (50-100 µg/m³).
# 3. Kondisi Cuaca (TEMP, PRES, DEWP, WSPM):
#     - TEMP (Suhu) dan PRES (Tekanan Udara) memiliki distribusi yang stabil tanpa banyak outliers, menunjukkan bahwa suhu dan tekanan udara relatif stabil di seluruh periode pengamatan.
#     - DEWP (Titik Embun) juga menunjukkan distribusi yang merata dengan sedikit outliers, mencerminkan kondisi kelembaban yang konsisten.
#     - WSPM (Kecepatan Angin) memiliki beberapa outliers di atas 4 m/s, namun mayoritas data menunjukkan kecepatan angin rendah (sekitar 1-2 m/s), yang bisa berkontribusi pada tingginya konsentrasi polutan di udara karena angin tidak cukup kuat untuk menyebarkannya.

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore all_stations_df_cleaned

# %%
all_stations_df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 303788 entries, 3 to 420767
# Data columns (total 19 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   No        303788 non-null  int64
#  1   year      303788 non-null  int64
#  2   month     303788 non-null  int64
#  3   day       303788 non-null  int64
#  4   hour      303788 non-null  int64
#  5   PM2.5     303788 non-null  float64
#  6   PM10      303788 non-null  float64
#  7   SO2       303788 non-null  float64
#  8   NO2       303788 non-null  float64
#  9   CO        303788 non-null  float64
#  10  O3        303788 non-null  float64
#  11  TEMP      303788 non-null  float64
#  12  PRES      303788 non-null  float64
#  13  DEWP      303788 non-null  float64
#  14  RAIN      303788 non-null  float64
#  15  wd        303788 non-null  object
#  16  WSPM      303788 non-null  float64
#  17  station   303788 non-null  object
#  18  datetime  303788 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(11), int64(5), object(2)
# memory usage: 46.4+ MB

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %%
all_stations_df_cleaned.describe(include="all")
# Out:
#                    No           year          month            day  \
# count   303788.000000  303788.000000  303788.000000  303788.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean     17896.895769    2014.691176       6.675511      15.864919
# min          1.000000    2013.000000       1.000000       1.000000
# 25%       9751.000000    2014.000000       4.000000       8.000000
# 50%      18436.000000    2015.000000       7.000000      16.000000
# 75%      26904.000000    2016.000000       9.000000      23.000000
# max      35064.000000    2017.000000      12.000000      31.000000
# std      10054.023416       1.174852       3.197039       8.790325
#
#                  hour          PM2.5           PM10            SO2  \
# count   303788.000000  303788.000000  303788.000000  303788.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean        11.136582      55.075240      75.633379       9.064356
# min          0.000000       2.000000       2.000000       0.285600
# 25%          5.000000      17.000000      29.000000       2.000000
# 50%         11.000000      42.000000      64.000000       5.000000
# 75%         17.000000      79.793428     108.000000      13.000000
# max         23.000000     241.000000     279.000000      39.412800
# std          7.026974      46.977192      55.762807       8.721232
#
#                   NO2             CO             O3           TEMP  \
# count   303788.000000  303788.000000  303788.000000  303788.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean        42.614902     861.026945      55.010873      14.771425
# min          1.026500     100.000000       0.214200     -19.900000
# 25%         22.000000     500.000000      19.000000       5.700000
# 50%         40.000000     800.000000      50.000000      16.800000
# 75%         58.000000    1200.000000      79.000000      23.600000
# max        118.047500    2300.000000     183.000000      41.600000
# std         25.317897     492.334161      43.114670      10.839304
#
#                  PRES           DEWP           RAIN      wd           WSPM  \
# count   303788.000000  303788.000000  303788.000000  303788  303788.000000
# unique            NaN            NaN            NaN      16            NaN
# top               NaN            NaN            NaN      NE            NaN
# freq              NaN            NaN            NaN   33403            NaN
# mean      1010.103055       3.785976       0.074382     NaN       1.597228
# min        982.400000     -43.400000       0.000000     NaN       0.000000
# 25%       1001.600000      -8.200000       0.000000     NaN       0.900000
# 50%       1009.100000       6.000000       0.000000     NaN       1.400000
# 75%       1018.200000      16.300000       0.000000     NaN       2.100000
# max       1042.800000      29.100000      72.500000     NaN       4.300000
# std         10.519033      14.025650       0.840209     NaN       0.954032
#
#         station                       datetime
# count    303788                         303788
# unique       12                            NaN
# top     Huairou                            NaN
# freq      27663                            NaN
# mean        NaN  2015-03-16 15:53:44.769905408
# min         NaN            2013-03-01 00:00:00
# 25%         NaN            2014-04-11 06:00:00
# 50%         NaN            2015-04-08 03:00:00
# 75%         NaN            2016-03-25 23:00:00
# max         NaN            2017-02-28 23:00:00
# std         NaN                            NaN

# %% [markdown]
# **Insight:**
# - Dataset ini memiliki distribusi yang beragam, terutama pada polutan seperti PM2.5, PM10, NO2, dan CO, yang menunjukkan adanya konsentrasi tinggi pada beberapa waktu.
# - Kondisi cuaca, terutama suhu dan tekanan, relatif stabil tetapi ada variasi yang signifikan pada kelembaban dan curah hujan.
# - Dataset ini memiliki cakupan waktu yang luas dari tahun 2013 hingga 2017, dengan konsistensi pengukuran bulanan dan jam yang baik.
# - Data ini siap untuk digunakan dalam analisis yang lebih mendalam, seperti analisis musiman, tren waktu, serta pengaruh kondisi cuaca terhadap polutan.

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %% [markdown]
# Bagaimana variasi kualitas udara (PM2.5, PM10) berdasarkan musim (spring, summer, autumn, winter)?
#
#   `Mengidentifikasi musim yang memiliki tingkat polusi tertinggi dan terendah untuk membantu membuat kebijakan mitigasi polusi udara yang lebih efektif di musim tertentu.`

# %%
# Membuat kolom season berdasarkan bulan
def get_season(month):
    if month in [3, 4, 5]:
        return 'Spring'
    elif month in [6, 7, 8]:
        return 'Summer'
    elif month in [9, 10, 11]:
        return 'Autumn'
    else:
        return 'Winter'

# Menambahkan kolom season pada dataframe
all_stations_df_cleaned['season'] = all_stations_df_cleaned['month'].apply(get_season)

# Membuat figure untuk plot
plt.figure(figsize=(14, 8))

# Subplot 1 untuk PM2.5
plt.subplot(1, 2, 1)
sns.boxplot(x='season', y='PM2.5', data=all_stations_df_cleaned, palette='Set3')
plt.title('Variation of PM2.5 by Season')
plt.xlabel('Season')
plt.ylabel('PM2.5 Concentration (µg/m³)')

# Subplot 2 untuk PM10
plt.subplot(1, 2, 2)
sns.boxplot(x='season', y='PM10', data=all_stations_df_cleaned, palette='Set3')
plt.title('Variation of PM10 by Season')
plt.xlabel('Season')
plt.ylabel('PM10 Concentration (µg/m³)')

# Menyesuaikan tata letak
plt.tight_layout()
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_19600\1839398423.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='season', y='PM2.5', data=all_stations_df_cleaned, palette='Set3')
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_19600\1839398423.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='season', y='PM10', data=all_stations_df_cleaned, palette='Set3')

# %% [markdown]
# `Insight`
#
# 1. PM2.5 (Partikulat Halus):
#   - Winter (Musim Dingin) menunjukkan konsentrasi PM2.5 yang sedikit lebih rendah dibandingkan musim lainnya. Meskipun demikian, masih ada beberapa outliers yang menunjukkan adanya tingkat polusi yang tinggi.
#   - Spring, Summer, dan Autumn (Musim Semi, Panas, dan Gugur) memiliki distribusi yang hampir serupa untuk PM2.5, dengan median konsentrasi yang sedikit lebih tinggi dibandingkan musim dingin. Namun, variasi antar musim tidak begitu signifikan.
#   - Outliers terlihat lebih banyak di musim Spring, Summer, dan Autumn, menunjukkan adanya momen atau lokasi di mana polusi udara lebih buruk di musim-musim ini, mungkin karena aktivitas manusia atau fenomena cuaca tertentu.
# 2. PM10 (Partikulat Kasar):
#   - Winter juga memiliki distribusi PM10 yang lebih rendah dibandingkan musim lainnya, dengan median yang lebih rendah dari Spring dan Autumn. Musim panas (Summer) memiliki konsentrasi PM10 yang sedikit lebih rendah daripada Spring dan Autumn, namun tetap lebih tinggi dibandingkan musim dingin.
#   - Sama seperti pada PM2.5, musim Spring dan Autumn menunjukkan distribusi yang lebih luas dengan median yang lebih tinggi, menunjukkan adanya polusi partikel kasar yang lebih signifikan di musim-musim ini.
#   - Outliers pada PM10 juga lebih sering terjadi di musim Spring dan Autumn, yang mungkin berhubungan dengan faktor lingkungan seperti debu atau polutan tambahan dari kegiatan industri atau transportasi.
#
# `Kesimpulan`
#   - Musim dingin (Winter) cenderung memiliki kualitas udara yang sedikit lebih baik dibandingkan dengan musim lainnya, baik untuk PM2.5 maupun PM10, meskipun masih ada outliers yang menunjukkan adanya polusi di beberapa waktu atau lokasi.
#   - Spring (Musim Semi) dan Autumn (Musim Gugur) cenderung memiliki kualitas udara yang lebih buruk, dengan konsentrasi partikel halus (PM2.5) dan partikel kasar (PM10) yang lebih tinggi. Ini dapat disebabkan oleh aktivitas manusia, seperti pembakaran atau peningkatan polusi karena perubahan cuaca.
#   - Summer (Musim Panas) berada di tengah, dengan tingkat polusi udara yang lebih rendah dibandingkan musim semi dan gugur, namun tetap lebih tinggi dari musim dingin.

# %% [markdown]
# ### Pertanyaan 2:

# %% [markdown]
# Apakah ada hubungan antara kecepatan angin (WSPM) dan konsentrasi PM2.5 di berbagai musim?
#
# `Mengidentifikasi apakah kecepatan angin mempengaruhi penyebaran atau akumulasi polusi udara (PM2.5) di musim-musim tertentu, yang bisa digunakan untuk memahami pola penyebaran polusi.`

# %%
# Membuat figure untuk visualisasi
plt.figure(figsize=(12, 8))

# Membuat scatter plot yang menunjukkan hubungan antara WSPM dan PM2.5, dibagi berdasarkan musim
sns.scatterplot(x='WSPM', y='PM2.5', hue='season', data=all_stations_df_cleaned, palette='Set1')

# Menambahkan judul dan label
plt.title('Relationship between Wind Speed (WSPM) and PM2.5 Concentration by Season', fontsize=14)
plt.xlabel('Wind Speed (WSPM) (m/s)', fontsize=12)
plt.ylabel('PM2.5 Concentration (µg/m³)', fontsize=12)

# Menampilkan plot
plt.show()

# %% [markdown]
# `Insight`
#
# 1. Hubungan Antara Kecepatan Angin dan PM2.5:
# - Secara umum, terlihat tren negatif di mana ketika kecepatan angin (WSPM) meningkat, konsentrasi PM2.5 cenderung menurun. Ini dapat dijelaskan oleh fakta bahwa angin lebih kuat biasanya membantu menyebarkan partikel polusi di udara, sehingga mengurangi konsentrasi PM2.5.
# - Pada kecepatan angin lebih rendah (0-1 m/s), konsentrasi PM2.5 cenderung lebih tinggi. Ini bisa disebabkan oleh kondisi udara yang lebih stagnan, yang memungkinkan partikel polutan untuk tetap terkonsentrasi di area tersebut.
#
# 2. Pengaruh Musim:
# - Winter (Musim Dingin): Pada musim ini, terlihat bahwa meskipun kecepatan angin relatif rendah (umumnya di bawah 3 m/s), konsentrasi PM2.5 cenderung lebih tinggi dibandingkan musim lainnya. Ini bisa disebabkan oleh aktivitas seperti pembakaran bahan bakar untuk pemanas atau cuaca dingin yang menahan polutan di dekat permukaan tanah.
# - Spring, Summer, Autumn (Musim Semi, Panas, Gugur): Pada musim ini, terlihat bahwa kecepatan angin lebih bervariasi, dan ketika kecepatan angin meningkat (di atas 2 m/s), konsentrasi PM2.5 cenderung berkurang. Pada musim ini, angin yang lebih kencang dapat membantu mengurangi polusi udara dengan menyebarkan partikel polutan.
#
# 3. Outliers dan Variasi:
# - Meskipun tren umumnya menunjukkan bahwa angin yang lebih kuat mengurangi konsentrasi PM2.5, ada beberapa outliers di mana konsentrasi PM2.5 tetap tinggi meskipun kecepatan angin cukup tinggi. Ini bisa diakibatkan oleh aktivitas manusia, seperti polusi dari kendaraan atau industri, yang tetap tinggi terlepas dari kondisi angin.
#
# `Kesimpulan`
# - Ada hubungan negatif antara kecepatan angin dan konsentrasi PM2.5, di mana kecepatan angin yang lebih tinggi cenderung mengurangi konsentrasi PM2.5.
# - Musim dingin (Winter) menunjukkan konsentrasi PM2.5 yang cenderung lebih tinggi bahkan pada kecepatan angin yang rendah, kemungkinan karena aktivitas musim dingin yang meningkatkan polusi.
# - Musim semi, panas, dan gugur menunjukkan bahwa kecepatan angin yang lebih tinggi cenderung mengurangi polusi udara lebih signifikan dibandingkan musim dingin.

# %% [markdown]
# ### Pertanyaan 3

# %% [markdown]
# Bagaimana distribusi polutan berbahaya (SO2, NO2, CO) di berbagai musim dan jam dalam sehari?
#
# `Mengetahui waktu-waktu kritis dengan konsentrasi polutan yang lebih tinggi di siang atau malam hari dapat membantu pengelolaan kualitas udara di waktu-waktu tertentu.`

# %%
# Membuat pivot table untuk SO2
pivot_so2 = all_stations_df_cleaned.pivot_table(index='hour', columns='season', values='SO2', aggfunc='mean')

# Membuat heatmap untuk SO2
plt.figure(figsize=(10, 6))
sns.heatmap(pivot_so2, cmap="YlGnBu", annot=False)
plt.title('Heatmap of SO2 Distribution by Hour and Season')
plt.ylabel('Hour of Day')
plt.xlabel('Season')
plt.show()

# Membuat pivot table untuk NO2
pivot_no2 = all_stations_df_cleaned.pivot_table(index='hour', columns='season', values='NO2', aggfunc='mean')

# Membuat heatmap untuk NO2
plt.figure(figsize=(10, 6))
sns.heatmap(pivot_no2, cmap="YlGnBu", annot=False)
plt.title('Heatmap of NO2 Distribution by Hour and Season')
plt.ylabel('Hour of Day')
plt.xlabel('Season')
plt.show()

# Membuat pivot table untuk CO
pivot_co = all_stations_df_cleaned.pivot_table(index='hour', columns='season', values='CO', aggfunc='mean')

# Membuat heatmap untuk CO
plt.figure(figsize=(10, 6))
sns.heatmap(pivot_co, cmap="YlGnBu", annot=False)
plt.title('Heatmap of CO Distribution by Hour and Season')
plt.ylabel('Hour of Day')
plt.xlabel('Season')
plt.show()

# %% [markdown]
# `Insight`
#
# 1. Distribusi SO2 (Sulfur Dioksida):
# - Musim Dingin (Winter): Konsentrasi SO2 cenderung lebih tinggi sepanjang hari, terutama pada jam-jam malam dan dini hari (18:00 hingga 09:00). Polusi SO2 tampaknya berkurang sedikit di siang hari.
# - Musim Semi dan Panas (Spring, Summer): Konsentrasi SO2 lebih rendah dan relatif stabil di semua jam. Polusi SO2 tampaknya paling sedikit terjadi pada musim panas.
# - Musim Gugur (Autumn): Distribusi SO2 di musim gugur agak serupa dengan musim dingin, meskipun polusi tidak setinggi di musim dingin. Konsentrasi SO2 lebih tinggi pada malam hari.
#
# 2. Distribusi NO2 (Nitrogen Dioksida):
# - Musim Dingin dan Gugur (Winter, Autumn): Konsentrasi NO2 lebih tinggi pada malam hari, terutama di antara jam 19:00 hingga 07:00. Polutan ini tampaknya meningkat pada malam hari ketika aktivitas manusia, seperti penggunaan bahan bakar untuk pemanas atau kendaraan, lebih intens.
# - Musim Panas dan Semi (Summer, Spring): Konsentrasi NO2 lebih rendah dan relatif stabil sepanjang hari. Ini menunjukkan bahwa pada musim panas dan semi, emisi NO2 lebih sedikit atau lebih cepat tersebar.
#
# 3. Distribusi CO (Karbon Monoksida):
# - Musim Dingin (Winter): Konsentrasi CO cenderung lebih tinggi di malam hari hingga dini hari (sekitar 18:00 hingga 09:00). Ini bisa terkait dengan peningkatan penggunaan pemanas atau pembakaran bahan bakar di musim dingin.
# - Musim Semi dan Panas (Spring, Summer): Konsentrasi CO lebih rendah di musim semi dan panas, dengan distribusi yang stabil sepanjang hari. Polusi CO tampaknya paling sedikit di musim panas.
# - Musim Gugur (Autumn): Distribusi CO di musim gugur serupa dengan musim dingin, dengan konsentrasi lebih tinggi di malam hingga pagi hari.
#
# `Kesimpulan`
# - SO2, NO2, dan CO semuanya menunjukkan konsentrasi tertinggi pada malam hari hingga dini hari, terutama di musim dingin dan gugur. Hal ini kemungkinan disebabkan oleh aktivitas manusia seperti penggunaan pemanas, kendaraan, dan pembakaran bahan bakar.
# - Musim Panas dan Semi umumnya menunjukkan konsentrasi yang lebih rendah untuk ketiga polutan, terutama di siang hari. Ini mungkin karena polusi lebih cepat tersebar akibat kondisi cuaca atau karena berkurangnya penggunaan bahan bakar.
# - Musim Dingin secara konsisten menunjukkan konsentrasi polutan yang lebih tinggi, kemungkinan karena efek inversi suhu yang menjebak polutan di permukaan tanah selama cuaca dingin.

# %% [markdown]
# ### Pertanyaan 4:
#
# Bagaimana pengaruh curah hujan (RAIN) terhadap konsentrasi polutan (PM2.5, PM10)?
#
# `Mengetahui apakah hujan membantu mengurangi polusi udara, yang bisa bermanfaat untuk perencanaan lingkungan di daerah perkotaan.`

# %%
# Membuat figure untuk scatter plot PM2.5
plt.figure(figsize=(14, 6))

# Subplot 1 untuk PM2.5 vs RAIN
plt.subplot(1, 2, 1)
sns.scatterplot(x='RAIN', y='PM2.5', data=all_stations_df_cleaned, alpha=0.5)
plt.title('Relationship between Rain and PM2.5 Concentration')
plt.xlabel('Rain (mm)')
plt.ylabel('PM2.5 Concentration (µg/m³)')

# Subplot 2 untuk PM10 vs RAIN
plt.subplot(1, 2, 2)
sns.scatterplot(x='RAIN', y='PM10', data=all_stations_df_cleaned, alpha=0.5)
plt.title('Relationship between Rain and PM10 Concentration')
plt.xlabel('Rain (mm)')
plt.ylabel('PM10 Concentration (µg/m³)')

# Menyesuaikan tata letak
plt.tight_layout()
plt.show()

# %% [markdown]
# `Insight`
#
# 1. Pengaruh Curah Hujan terhadap PM2.5:
# - Sebagian besar data dengan curah hujan 0 mm menunjukkan konsentrasi PM2.5 yang bervariasi, dari rendah hingga sangat tinggi (hingga lebih dari 200 µg/m³).
# - Penurunan Konsentrasi dengan Curah Hujan: Ketika curah hujan mulai meningkat (>0 mm), terlihat bahwa konsentrasi PM2.5 cenderung menurun secara bertahap. Pada curah hujan yang lebih besar (sekitar 10 mm atau lebih), PM2.5 cenderung berada di kisaran konsentrasi yang lebih rendah.
# - Kesimpulan untuk PM2.5: Curah hujan tampaknya membantu menurunkan konsentrasi PM2.5 di udara. Efek "pembersihan" oleh curah hujan ini menurunkan polutan halus dari atmosfer.
#
# 2. Pengaruh Curah Hujan terhadap PM10:
# - Pengamatan Umum: Sama seperti PM2.5, saat curah hujan 0 mm, konsentrasi PM10 sangat bervariasi, dengan beberapa titik menunjukkan konsentrasi yang sangat tinggi (>250 µg/m³).
# - Penurunan Konsentrasi dengan Curah Hujan: Ketika curah hujan meningkat, terdapat tren penurunan konsentrasi PM10. Namun, penurunan ini tampaknya sedikit lebih lambat dibandingkan PM2.5. Meski curah hujan tinggi (>20 mm), masih ada beberapa data dengan konsentrasi PM10 yang tinggi.
# - Kesimpulan untuk PM10: Curah hujan juga membantu menurunkan konsentrasi PM10, namun efeknya mungkin sedikit lebih lemah dibandingkan dengan PM2.5. Polutan yang lebih besar seperti PM10 mungkin memerlukan curah hujan yang lebih tinggi untuk benar-benar dibersihkan dari atmosfer.
#
# `Kesimpulan`
# - Curah hujan memiliki dampak positif dalam mengurangi konsentrasi polutan udara, khususnya PM2.5 dan PM10. Ketika curah hujan meningkat, konsentrasi polutan cenderung menurun, karena hujan membantu membersihkan polutan dari udara.
# - PM2.5 tampaknya lebih cepat menurun dengan curah hujan dibandingkan PM10, mungkin karena ukurannya yang lebih kecil dan lebih mudah tersapu oleh air hujan.
# - Efek hujan menjadi lebih terlihat pada intensitas curah hujan di atas 10 mm, di mana konsentrasi polutan lebih stabil pada level yang lebih rendah.

# %% [markdown]
# ### Pertanyaan 5:
#
# Apakah ada tren perubahan kualitas udara (PM2.5, PM10) dari tahun 2013 hingga 2017?
#
# `Mengetahui apakah kualitas udara semakin membaik atau memburuk seiring waktu, dan dapat menjadi dasar untuk mengevaluasi efektivitas kebijakan pengurangan emisi yang telah diterapkan.`

# %%
if 'datetime' not in all_stations_df_cleaned.columns:
    all_stations_df_cleaned['datetime'] = pd.to_datetime(
        all_stations_df_cleaned[['year', 'month', 'day', 'hour']]
    )

# Mengelompokkan data berdasarkan tahun dan menghitung rata-rata PM2.5 dan PM10 per tahun
yearly_avg = all_stations_df_cleaned.groupby(all_stations_df_cleaned['datetime'].dt.year)[['PM2.5', 'PM10']].mean().reset_index()

# Membuat figure untuk line plot
plt.figure(figsize=(10, 6))

# Plot tren PM2.5
sns.lineplot(x='datetime', y='PM2.5', data=yearly_avg, marker='o', label='PM2.5', color='b')

# Plot tren PM10
sns.lineplot(x='datetime', y='PM10', data=yearly_avg, marker='o', label='PM10', color='r')

# Menambahkan judul dan label
plt.title('Tren Perubahan Kualitas Udara (PM2.5 dan PM10) dari 2013 hingga 2017', fontsize=14)
plt.xlabel('Tahun', fontsize=12)
plt.ylabel('Konsentrasi Polutan (µg/m³)', fontsize=12)

# Menambahkan legenda
plt.legend()

# Menampilkan plot
plt.show()

# %% [markdown]
# `Insight`
#
# 1. PM2.5 (Partikulat Halus):
# - Konsentrasi PM2.5 pada tahun 2013 berada di kisaran 60 µg/m³.
# - Setelah 2014, terlihat adanya penurunan konsisten dalam konsentrasi PM2.5, dengan penurunan yang cukup signifikan terutama antara tahun 2016 dan 2017. Pada tahun 2017, konsentrasi PM2.5 berada di sekitar 45 µg/m³, yang lebih rendah dibandingkan tahun-tahun sebelumnya.
# - Tren Penurunan: Secara keseluruhan, terdapat penurunan konsentrasi PM2.5 dari tahun 2013 hingga 2017, yang menunjukkan perbaikan kualitas udara dalam hal partikulat halus.
#
# 2. PM10 (Partikulat Kasar):
# - Konsentrasi PM10 pada tahun 2013 berada di sekitar 75 µg/m³.
# - Konsentrasi PM10 meningkat pada tahun 2014 ke sekitar 85 µg/m³, kemudian mulai menurun secara bertahap setelah tahun 2014. Penurunan yang lebih tajam terjadi antara tahun 2016 dan 2017, di mana konsentrasi PM10 turun ke sekitar 65 µg/m³.
# - Tren Penurunan: Seperti PM2.5, PM10 juga menunjukkan penurunan dari puncaknya pada 2014 hingga 2017, menandakan bahwa kualitas udara dalam hal partikulat kasar juga mengalami perbaikan.
#
# `Kesimpulan`
# - Kualitas udara secara umum meningkat dari tahun 2013 hingga 2017, dengan penurunan konsentrasi baik pada PM2.5 maupun PM10. Hal ini mungkin disebabkan oleh langkah-langkah kebijakan lingkungan yang lebih ketat atau perubahan dalam aktivitas industri dan transportasi.
# - PM2.5 dan PM10 menunjukkan tren yang sama, dengan penurunan yang signifikan setelah 2014, terutama pada tahun 2017.

# %% [markdown]
# Simpan dataframe yang sudah bersih ke file csv untuk proses pembuatan dashboard

# %%
all_stations_df_cleaned = all_stations_df_cleaned.drop(columns=['No'])

# %%
all_stations_df_cleaned.to_csv("./data/clean/all-data.csv", index=False)

# %% [markdown]
# `================== Terima Kasih ==================`
